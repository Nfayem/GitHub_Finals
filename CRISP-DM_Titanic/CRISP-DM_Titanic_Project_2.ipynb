# %% [markdown]
# # Individual Project - Titanic

# %% [markdown]
# ## Author(s): Nfayem Imoro

# %% [markdown]
# ## Table of Contents
#
# [**Step 3: Data Preparation**](#Step-3:-Data-Preparation)
# - [**Deal with Missing Data**](#Deal-with-Missing-Data)
# - [**Feature Engineering**](#Feature-Engineering)
#
# [**Step 4: Modeling**](#Step-4:-Modeling)

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
#
# This initial phase focuses on understanding the project objectives and requirements from a business perspective, and then converting this knowledge into a data mining problem definition, and a preliminary plan designed to achieve the objectives.
# #### Titanic Story
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class passengers.
#
# #### Objective
#  we will build a regression model to predict ticket price(Fare).

# %% [markdown]
# ### Load Data
#
# This dataset is in titanic-231005-181053.csv. Make sure the file is in the current folder. Please download the file from [here](https://github.com/data-lessons/python-business/tree/gh-pages/data) if you haven't done so yet.

# %%
# Import the relevant libraries
import pandas as pd
import statsmodels.formula.api as smf
import warnings

# Suppressing all warnings to avoid cluttering the output
warnings.filterwarnings("ignore")

# %%
# Read the Titanic dataset from a CSV file 
df_titanic = pd.read_csv("titanic-231005-181053.csv")

# Display the first few rows of the DataFrame
print()
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Cabin Embarked
# 0      0         A/5 21171     $7.25   NaN        S
# 1      0          PC 17599  $71.2833   C85        C
# 2      0  STON/O2. 3101282    $7.925   NaN        S
# 3      0            113803     $53.1  C123        S
# 4      0            373450     $8.05   NaN        S

# %% [markdown]
# ### Clean up Fare, Convert to Float
# Strip "$" from Fare, convert datatype to float.

# %%
# Removing the dollar sign from the "Fare" column and then converting the result to float data type.
df_titanic["Fare"] = df_titanic["Fare"].str.replace('$', "").astype(float)

# Display verbose summary information about the modified DataFrame
print()
df_titanic.info(memory_usage = "deep")

# # Display the first few rows of the modified DataFrame
print()
df_titanic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 315.0 KB
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
# ## Step 3: Data Preparation
# Create new features through feature engineering; Deal with missing values; Clean up data, ie. strip extra white spaces in string values. We will focus on dealing with missing data in this phrase.

# %%
#check all missing data
df_titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Deal with Missing Data
# We will demonstrate filling with mean/mode and estimate from other columns.
#
# #### Fill with Mean/Mode
# Embarked only has 2 missing values and there is no obvious way to estimate the missing walue, we will simply fill it with mode of the column, or 'S'

# %% [markdown]
# ##### Task 12: Fill missing Embarked with mode

# %%
# Fill missing values in the 'Embarked' column of the Titanic dataset with the most frequent value
df_titanic["Embarked"].fillna(df_titanic["Embarked"].mode()[0], inplace=True)

# Display the updated DataFrame
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Fill with Estimated Value
#
# A title is a word used in a person's name, in certain contexts. It may signify either veneration, an official position, or a professional or academic qualification. It's a good indication of age, for example, Mr is for adult man, Master is for young boys.
#
# If we look at all names of Titanic passengers, we can see that the name is in format Last, Title. First. We can use this information to estimate missing ages.
#
# - First, we will use regular expression to extract title from name.
# - Then we will convert title to upper case.
# - Then we fill missing age with mean age of specific title.

# %%
# Extract title from name
df_titanic["Title"] = df_titanic.Name.str.extract("([A-Za-z]+\.)")

# Display the updated DataFrame
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### Task 13: convert title to upper case.
# To ensure we get accurate mean age of each initial, we convert initial to all upper case.

# %%
# Convert the 'Title' column in the Titanic DataFrame to uppercase
df_titanic["Title"] = df_titanic["Title"].str.upper()

# Display the updated DataFrame
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ##### Task 14: Fill missing age with mean age of the title

# %%
# Count the occurrences of each unique value in the 'Title' column of the DataFrame
df_titanic.Title.value_counts()
# Out:
# Title
# MR.          517
# MISS.        182
# MRS.         125
# MASTER.       40
# DR.            7
# REV.           6
# MLLE.          2
# MAJOR.         2
# COL.           2
# COUNTESS.      1
# CAPT.          1
# MS.            1
# SIR.           1
# LADY.          1
# MME.           1
# DON.           1
# JONKHEER.      1
# Name: count, dtype: int64

# %%
# Fill missing values in the 'Age' column with the mean age corresponding to each passenger's 'Title'
df_titanic["Age"].fillna(df_titanic.groupby("Title")["Age"].transform("mean"), inplace=True)

# Display verbose summary information about the modified DataFrame
print()
df_titanic.info(memory_usage = "deep")

# # Display the updated DataFrame
print()
df_titanic
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  Title        891 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 368.0 KB
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ...

# %% [markdown]
# ### Feature Engineering
# We'll create a new column FamilySize. There are 2 columns related to family size, parch indicates parent or children number, Sibsp indicates sibling and spouse number.
#
# Take one name 'Asplund' as example, we can see that total family size is 7(Parch + SibSp + 1), and each family member has same Fare, which means the Fare is for the whole group. So family size will be an important feature to predict Fare. There're only 4 Asplunds out of 7 in the dataset becasue the dataset is only a subset of all passengers.

# %%
# Select rows in the DataFrame where the 'Name' column does not contain 'Asplund'
df_titanic[~df_titanic["Name"].str.contains("Asplund")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# ##### Task 15: Create column 'FamilySize'
# FamilySize = Parch + SibSp + 1

# %%
# Calculate the total family size
df_titanic["FamilySize"] = df_titanic["Parch"] + df_titanic["SibSp"] + 1

# Display the updated DataFrame
df_titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# [Back to Top](#Table-of-Contents)
#
# ## Step 4: Modeling
#
# Now we have a relatively clean dataset(Except for Cabin column which has many missing values). We can do a classification on Survived to predict whether a passenger could survive the desaster or a regression on Fare to predict ticket fare. This dataset is not a good dataset for regression. But since we don't talk about classification in this workshop we will construct a linear regression on Fare in this exercise.

# %% [markdown]
# ##### Task 16: Contruct a regression on Fare
# Construct regression model with statsmodels.
#
# Pick Pclass, Embarked, FamilySize as independent variables.

# %%
# Fit Ordinary Least Squares (OLS) regression model to predict 'Fare' based on 'Pclass', 'Embarked', and 'FamilySize' variables
result = smf.ols("Fare ~ C(Pclass) + C(Embarked) + FamilySize", data=df_titanic).fit()

# Display summary statistics of the regression model
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   Fare   R-squared:                       0.427
# Model:                            OLS   Adj. R-squared:                  0.424
# Method:                 Least Squares   F-statistic:                     131.9
# Date:                Sun, 21 Apr 2024   Prob (F-statistic):          1.92e-104
# Time:                        08:20:29   Log-Likelihood:                -4495.8
# No. Observations:                 891   AIC:                             9004.
# Df Residuals:                     885   BIC:                             9032.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [raw]
# Conclusion:
#
# Upon analysis of the provided data, the model demonstrates a statistically significant explanatory capacity, albeit moderately so, as indicated by an R-squared value of 0.427. This suggests that approximately 42.7% of the variance in fare can be explained by the predictors incorporated into the model. However, it's noteworthy that the adjusted R-squared value of 0.424 is marginally lower than the R-squared, indicating that the inclusion of additional predictors may not be significantly augmenting the model's explanatory power.
#
# The predictor equation derived from the analysis is as follows:
#
# Fare = $79.2989 + $(C(Pclass)[T.2]×−59.0955) + $(C(Pclass)[T.3]×−68.8790) + $(C(Embarked)[T.Q]×−11.8147) + $(C(Embarked)[T.S]×−14.9202)+ $(7.8256×FamilySize)
#
# This equation provides insight into how each predictor influences the fare. The y-intercept, $79.2989, represents the expected fare when all predictors are zero. For instance, a passenger belonging to the second class (C(Pclass)[T.2]) is associated with a decrease in fare by $59.0955, while a passenger in the third class (C(Pclass)[T.3]) is linked to a reduction by $68.8790. Similarly, embarking from Queenstown (C(Embarked)[T.Q]) or Southampton (C(Embarked)[T.S]) corresponds to fare decreases of $11.8147 and $14.9202, respectively. Additionally, each increment in family size results in a fare increase of $7.8256.
